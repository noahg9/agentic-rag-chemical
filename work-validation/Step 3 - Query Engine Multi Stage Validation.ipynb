# %% [markdown]
# ## Step 3 Validation: Query Engine Multi-Stage QA with Intermediate Outputs
# ## This notebook validates the multi-stage QA process and prints intermediate outputs:
# ### 1. Query decomposition (sub-queries).
# ### 2. Retrieval of documents for each sub-query.
# ### 3. Synthesis of the final answer.
# ### 4. Final summary with confidence rating.
#
# ### The process uses LangSmith's Client for tracing, and the retriever benefits from earlier reranking.

# %%
from query_engine import QueryEngine, QueryResult


import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


from langsmith import Client, traceable
from llm import get_llm
from retriever import setup_work_retriever
from text_processing import dynamic_text_splitter
from document_loader import load_work_instructions
from config import RESOURCES_PATH

# Initialize LangSmith Client for tracing.
client = Client()
# Out:
# /home/zamlamb/KdG/agenticrag/.venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:502: UserWarning: <built-in function any> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/zamlamb/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/zamlamb/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-POL-R002\nDate : 14/11/2022\nVersion: 2', 'Manual Loading of Solids']], [{'1': '2', 'Ensure a vacuum of 700 mb in R-002. Place the portable hopper next to the reactor.': 'Wear the specific PPE: neoprene gloves and a face shield for the helmet.'}, {'1': '3', 'Ensure a vacuum of 700 mb in R-002. Place the portable hopper next to the reactor.': 'Remove the inlet cap from the reactor and the hose cap from the portable hopper.'}], [{'4': '5', 'Connect the hose to the reactor inlet.': 'Open the hopper lid and load the sack. Open the manual valve under the portable\nhopper to approximately 40º to allow air entry.'}, {'4': '6', 'Connect the hose to the reactor inlet.': 'Request the opening of valve H20202.'}, {'4': '7', 'Connect the hose to the reactor inlet.': 'Once the hopper is empty, request the closure of valve H20202.'}, {'4': '8', 'Connect the hose to the reactor inlet.': 'Close the hopper lid and the lower valve. Disconnect the hose and place the caps\nback on the reactor inlet and hose.'}, {'4': '9', 'Connect the hose to the reactor inlet.': 'Move the portable hopper to its designated location. Leave the area clean.'}, {'4': '1\n0', 'Connect the hose to the reactor inlet.': 'Dispose of empty sacks in the nearest RES-34 big bag.'}]]
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-POL-R001-01\nDate : 20/06/2020\nVersion: 2', 'Hypophosphorous Acid Addition']], [{'1': '2', 'Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron.': 'Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001.'}, {'1': '3', 'Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron.': 'With the reactor under vacuum, remove the cap from the acid container and insert\nCane A. Slowly open manual valve 2 to load hypophosphorous acid into R-001. The\namount loaded into the reactor is controlled by the weight difference on the scale.\nOnce the desired amount has been loaded, lift the cane and allow air to be drawn in\nuntil it is clean.'}], [{'Column1': '4', 'Column2': 'Place Cane A in its position, close manual valve 1, and close the acid container.'}, {'Column1': '5', 'Column2': 'If the hypophosphorous acid container is empty, it must be placed in the exit area,\nand the new container from the entry area should be placed on the scale. It is the\nresponsibility of the field operator to collect empty containers and ensure a spare\ncontainer is available in the entry area.'}]]
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-CIS-25\nDate : 10/11/2020\nVersion: 3', 'Tanker Unloading to SD-05, SD-06,\nSD-07, SD-08, and SD-12']], [{'1': '2', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Open the steam passage valves to heat the pipes and installations.'}, {'1': '3', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Specific PPE for Operator and Driver:\n• SD-05, SD-06, and SD-08: Neoprene gloves and face shield for helmet.\n• SD-07 and SD-12: Neoprene gloves, face shield for helmet, and apron.'}, {'1': '4', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Position the tanker in the designated area. Chock and signal it.'}, {'1': '5', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Ensure the tanker is sealed.\nDriver: Climb with a harness, lifeline, and raised guardrail to open the hatches and\ntop port. For SD-06, SD-07, and SD-12, take a sample from the top port using the\ndedicated tool. Close the top port and hatches.\nDeliver the sample with the analysis report to the laboratory.'}, {'1': '6', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Connect the sampling valve arm to the coupling. Ensure the valve is closed.'}, {'1': '7', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Take the dedicated hose, remove the cap, and connect it to the sampling piece.\nHandle the hoisted hose with care.'}], [{'8': '9', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Driver: Using a lifeline, harness, and safety guardrail, open the bottom valve.\nOpen the tanker outlet valve and the manual line valve.'}, {'8': '10', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Select the unloading tank and request plant authorization. Start the pump.\nDuring unloading, the driver must remain outside the cab and in view.'}, {'8': '11', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Check and complete tanker documentation. Monitor for leaks and tank level during\nunloading.'}, {'8': '12', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'At the end of unloading, verify complete tanker emptying.\nDriver: Using a harness, lifeline, and guardrail, close the bottom valve, hatches,\nand tanker outlet valve.'}, {'8': '13', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Stop the pump and connect the air hose to the tanker outlet piece to blow out the\nhose and line to the tank.'}, {'8': '14', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control labo ...
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-SUL-\nLaboratory\nDate : 31/7/2020\nVersion: 1', 'Sulfated Analysis by HPLC']], [{'1': '2', 'Puncture the sample. Open the slot to insert the needle and introduce the sample.\nRemove the needle and close the slot.': 'Enter the Sample Name and in Method select the corresponding base for the analysis\nto be performed. Press Inject.'}], [{'3': '4', 'Click on Integrate and Quantitate. Click on Send data to review to visualize the\nresults.': 'Click on the icon, and the window Specify single inject Parameters will appear.'}]]
# Loaded workinst embeddings from cache.

# %%
@traceable(project_name="workstations", client=client)
def validate_query_processing(user_query: str, retriever_instance) -> QueryResult:
    # Instantiate the QueryEngine with desired parameters.
    query_engine_instance = QueryEngine(debug_mode=True, confidence_threshold=80)

    # Execute the query and get the result.
    result = query_engine_instance.query_documents_advanced(user_query, retriever_instance)
    return result

# %%
# Load work instructions and split into chunks.
documents = load_work_instructions(RESOURCES_PATH)
document_chunks = dynamic_text_splitter(documents, default_chunk_size=500)
print(f"Loaded {len(documents)} document(s) and created {len(document_chunks)} chunks.")
# Out:
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-POL-R002\nDate : 14/11/2022\nVersion: 2', 'Manual Loading of Solids']], [{'1': '2', 'Ensure a vacuum of 700 mb in R-002. Place the portable hopper next to the reactor.': 'Wear the specific PPE: neoprene gloves and a face shield for the helmet.'}, {'1': '3', 'Ensure a vacuum of 700 mb in R-002. Place the portable hopper next to the reactor.': 'Remove the inlet cap from the reactor and the hose cap from the portable hopper.'}], [{'4': '5', 'Connect the hose to the reactor inlet.': 'Open the hopper lid and load the sack. Open the manual valve under the portable\nhopper to approximately 40º to allow air entry.'}, {'4': '6', 'Connect the hose to the reactor inlet.': 'Request the opening of valve H20202.'}, {'4': '7', 'Connect the hose to the reactor inlet.': 'Once the hopper is empty, request the closure of valve H20202.'}, {'4': '8', 'Connect the hose to the reactor inlet.': 'Close the hopper lid and the lower valve. Disconnect the hose and place the caps\nback on the reactor inlet and hose.'}, {'4': '9', 'Connect the hose to the reactor inlet.': 'Move the portable hopper to its designated location. Leave the area clean.'}, {'4': '1\n0', 'Connect the hose to the reactor inlet.': 'Dispose of empty sacks in the nearest RES-34 big bag.'}]]
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-POL-R001-01\nDate : 20/06/2020\nVersion: 2', 'Hypophosphorous Acid Addition']], [{'1': '2', 'Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron.': 'Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001.'}, {'1': '3', 'Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron.': 'With the reactor under vacuum, remove the cap from the acid container and insert\nCane A. Slowly open manual valve 2 to load hypophosphorous acid into R-001. The\namount loaded into the reactor is controlled by the weight difference on the scale.\nOnce the desired amount has been loaded, lift the cane and allow air to be drawn in\nuntil it is clean.'}], [{'Column1': '4', 'Column2': 'Place Cane A in its position, close manual valve 1, and close the acid container.'}, {'Column1': '5', 'Column2': 'If the hypophosphorous acid container is empty, it must be placed in the exit area,\nand the new container from the entry area should be placed on the scale. It is the\nresponsibility of the field operator to collect empty containers and ensure a spare\ncontainer is available in the entry area.'}]]
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-CIS-25\nDate : 10/11/2020\nVersion: 3', 'Tanker Unloading to SD-05, SD-06,\nSD-07, SD-08, and SD-12']], [{'1': '2', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Open the steam passage valves to heat the pipes and installations.'}, {'1': '3', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Specific PPE for Operator and Driver:\n• SD-05, SD-06, and SD-08: Neoprene gloves and face shield for helmet.\n• SD-07 and SD-12: Neoprene gloves, face shield for helmet, and apron.'}, {'1': '4', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Position the tanker in the designated area. Chock and signal it.'}, {'1': '5', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Ensure the tanker is sealed.\nDriver: Climb with a harness, lifeline, and raised guardrail to open the hatches and\ntop port. For SD-06, SD-07, and SD-12, take a sample from the top port using the\ndedicated tool. Close the top port and hatches.\nDeliver the sample with the analysis report to the laboratory.'}, {'1': '6', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Connect the sampling valve arm to the coupling. Ensure the valve is closed.'}, {'1': '7', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Take the dedicated hose, remove the cap, and connect it to the sampling piece.\nHandle the hoisted hose with care.'}], [{'8': '9', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Driver: Using a lifeline, harness, and safety guardrail, open the bottom valve.\nOpen the tanker outlet valve and the manual line valve.'}, {'8': '10', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Select the unloading tank and request plant authorization. Start the pump.\nDuring unloading, the driver must remain outside the cab and in view.'}, {'8': '11', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Check and complete tanker documentation. Monitor for leaks and tank level during\nunloading.'}, {'8': '12', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'At the end of unloading, verify complete tanker emptying.\nDriver: Using a harness, lifeline, and guardrail, close the bottom valve, hatches,\nand tanker outlet valve.'}, {'8': '13', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'Stop the pump and connect the air hose to the tanker outlet piece to blow out the\nhose and line to the tank.'}, {'8': '14', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece. Deliver the sample to the control labo ...
# Extracted PDF table data: [[['Work Instruction\nDocument Code: ZF-IT-SUL-\nLaboratory\nDate : 31/7/2020\nVersion: 1', 'Sulfated Analysis by HPLC']], [{'1': '2', 'Puncture the sample. Open the slot to insert the needle and introduce the sample.\nRemove the needle and close the slot.': 'Enter the Sample Name and in Method select the corresponding base for the analysis\nto be performed. Press Inject.'}], [{'3': '4', 'Click on Integrate and Quantitate. Click on Send data to review to visualize the\nresults.': 'Click on the icon, and the window Specify single inject Parameters will appear.'}]]
# Loaded 4 document(s) and created 37 chunks.

# %%
# Choose the model for the Query Engine.
model_choice = "azure"  # Change to "ollama" or "qwen2.5" as needed.
llm_instance = get_llm(model_choice)
# Out:
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'ce253368-00bf-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '4764f529-0248-45cf-a4b6-bfb476ec68e1'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 401ABC2907CE4EBB990DCE0C8B65E845 Ref B: VIEEDGE2512 Ref C: 2025-03-14T10:33:46Z'
#     'Date': 'Fri, 14 Mar 2025 10:33:46 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'cf8b751e-00bf-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'e214b97c-0383-4373-a64b-8b5242ad3642'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: C3C4387044F246F5B351D4C5A1463FAB Ref B: VIEEDGE2512 Ref C: 2025-03-14T10:33:46Z'
#     'Date': 'Fri, 14 Mar 2025 10:33:47 GMT'

# %%
# Setup the retriever from the work chunks.
retriever_instance = setup_work_retriever(document_chunks)
# Define the two queries
queries = [
    "How do I handle hypophosphorous acid?",
    "What safety measures are required for unloading a tanker?",
    "What are the steps for HPLC Sulfated Analysis?",
    "How do I properly clean the reactor after use?",
    "What is the required PPE for handling sulfuric acid?"
]
# Out:
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '27e42a1c-00c0-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '945a504c-3176-4110-ba4f-413284ba938f'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 0DAE844433ED4F10813FA3AACF457F67 Ref B: VIEEDGE1215 Ref C: 2025-03-14T10:36:16Z'
#     'Date': 'Fri, 14 Mar 2025 10:36:16 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '2916d52e-00c0-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'f28e6592-1d3b-4d85-aec0-0b7d3d1da878'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: F0D7E85C8149489A860555A2A68FBE2E Ref B: VIEEDGE1215 Ref C: 2025-03-14T10:36:17Z'
#     'Date': 'Fri, 14 Mar 2025 10:36:16 GMT'
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333/collections/work_instructions_RAG "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/work_instructions_RAG/points?wait=true "HTTP/1.1 200 OK"

# %%
# Display the final output with full metadata for each source document.
# Initialize the QueryEngine with debug mode for detailed output
for query in queries:
    query_result = validate_query_processing(query, retriever_instance)
    print("=" * 80)
    print(f"Processing Query: {query}")
    print("=" * 80)
    print("Final Answer:", query_result.answer)
    print("Confidence:", query_result.confidence, "%")
    print("Source Documents Metadata:")
    for source in query_result.source_documents:
        print("-" * 40)
        for key, value in source.items():
            print(f"{key}: {value}")
# Out:
# /home/zamlamb/KdG/agenticrag/llm.py:80: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   self._ollama = Ollama(model=model, temperature=temperature)
# /home/zamlamb/KdG/agenticrag/llm.py:87: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return self._ollama(prompt, stop=stop)
# /home/zamlamb/KdG/agenticrag/query_engine.py:269: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = qa_chain_instance.retriever.get_relevant_documents(subq)
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/work_instructions_RAG/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/work_instructions_RAG/points/search "HTTP/1.1 200 OK"
# INFO:query_engine:Retrieved document content: Antwerp – Paris - Barcelona – Madrid – London - Lyon – Lille – Rotterdam - Cologne – Geneva
# Almeria - Porto - Tarragona - Krakow – Zaporizhzhia - New York - Houston
# [Publish Date]
# [Comments]
# Place Cane A in its position, close manual valve 1, and close the acid container. 4
# If the hypophosphorous acid container is empty, it must be placed in the exit area,
# and the new container from the entry area should be placed on the scale. It is the
# responsibility of the field operator to collect empty cont
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '1869e19c-b125-4460-af72-28d875008dd1', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: Antwerp – Paris - Barcelona – Madrid – London - Lyon – Lille – Rotterdam - Cologne – Geneva
# Almeria - Porto - Tarragona - Krakow – Zaporizhzhia - New York - Houston
# [Publish Date]
# [Comments]
# Place Cane A in its position, close manual valve 1, and close the acid container. 4
# If the hypophosphorous acid container is empty, it must be placed in the exit area,
# and the new container from the entry area should be placed on the scale. It is the
# responsibility of the field operator to collect empty cont
# INFO:query_engine:Retrieved document metadata: {'metadata': {}, '_id': 'e1753920-5f08-489a-8308-827159430a1e', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: Antwerp – Paris - Barcelona – Madrid – London - Lyon – Lille – Rotterdam - Cologne – Geneva
# Almeria - Porto - Tarragona - Krakow – Zaporizhzhia - New York - Houston
# [Publish Date]
# [Comments]
# Place Cane A in its position, close manual valve 1, and close the acid container. 4
# If the hypophosphorous acid container is empty, it must be placed in the exit area,
# and the new container from the entry area should be placed on the scale. It is the
# responsibility of the field operator to collect empty cont
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': 'cd8194bf-3474-4139-8a9c-757d6e9438cd', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: AG Solution Spain S.A.U. C. Pujades 350, Planta 4, Puerta 1
# 08019 Barcelona – Spain
# www.agsolutiongroup.com
# +34 93 624 02 75
# ES A 65931651
# Work Instruction
# Document Code: ZF-IT-POL-R001-01
# Hypophosphorous Acid Addition
# Date : 20/06/2020
# Version: 2
# Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron. 1
# Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001. 2
# With the reactor under vacuum, remove the cap from the acid container and insert
# Cane A
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '01daa77c-8745-4e40-b622-b1f8ba3aeb1c', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: AG Solution Spain S.A.U. C. Pujades 350, Planta 4, Puerta 1
# 08019 Barcelona – Spain
# www.agsolutiongroup.com
# +34 93 624 02 75
# ES A 65931651
# Work Instruction
# Document Code: ZF-IT-POL-R001-01
# Hypophosphorous Acid Addition
# Date : 20/06/2020
# Version: 2
# Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron. 1
# Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001. 2
# With the reactor under vacuum, remove the cap from the acid container and insert
# Cane A
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '43e2c355-e5e9-417a-8f45-35371b941654', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: AG Solution Spain S.A.U. C. Pujades 350, Planta 4, Puerta 1
# 08019 Barcelona – Spain
# www.agsolutiongroup.com
# +34 93 624 02 75
# ES A 65931651
# Work Instruction
# Document Code: ZF-IT-POL-R001-01
# Hypophosphorous Acid Addition
# Date : 20/06/2020
# Version: 2
# Wear the specific PPE: neoprene gloves, face shield for the helmet, and an apron. 1
# Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001. 2
# With the reactor under vacuum, remove the cap from the acid container and insert
# Cane A
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '0aaa2ea4-49b0-42fc-9c96-afdeda68de5d', '_collection_name': 'work_instructions_RAG'}
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '86a9bb98-00c0-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '329585ad-bc23-4634-a22b-a6f4736d2893'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 6C0EAC652D9C44FBBA7FF0049549C00F Ref B: VIEEDGE2806 Ref C: 2025-03-14T10:38:55Z'
#     'Date': 'Fri, 14 Mar 2025 10:38:56 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '8838e89e-00c0-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'a9d48981-5786-4479-974b-e2e091640a68'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: E864F6573DC54F8B83A074ADC6F48A63 Ref B: VIEEDGE2806 Ref C: 2025-03-14T10:38:56Z'
#     'Date': 'Fri, 14 Mar 2025 10:38:58 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3493'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '89713b8a-00c0-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 429
# Response headers:
#     'Content-Length': '388'
#     'Content-Type': 'application/json'
#     'Retry-After': '19'
#     'x-ratelimit-reset-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'x-ms-client-request-id': '89713b8a-00c0-11f0-a4e6-38fc98f12ce6'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'policy-id': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:38:58 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3493'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '89713b8a-00c0-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 429
# Response headers:
#     'Content-Length': '387'
#     'Content-Type': 'application/json'
#     'Retry-After': '7'
#     'x-ratelimit-reset-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'x-ms-client-request-id': '89713b8a-00c0-11f0-a4e6-38fc98f12ce6'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'policy-id': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:39:17 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3493'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '89713b8a-00c0-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '1275'
#     'Content-Type': 'application/json'
#     'azureml-internal-engineid': 'REDACTED'
#     'azureml-model-id': 'REDACTED'
#     'openai-internal-encoding': 'REDACTED'
#     'openai-internal-engine-tags': 'REDACTED'
#     'openai-internal-engine-weight': 'REDACTED'
#     'openai-internal-sampling-args': 'REDACTED'
#     'openai-model': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'x-accel-buffering': 'REDACTED'
#     'x-ms-rai-invoked': 'REDACTED'
#     'x-request-id': 'REDACTED'
#     'azureml-destination-model-group': 'REDACTED'
#     'azureml-destination-region': 'REDACTED'
#     'azureml-destination-deployment': 'REDACTED'
#     'azureml-destination-endpoint': 'REDACTED'
#     'azureml-model-deployment': 'REDACTED'
#     'azureml-model-session': 'REDACTED'
#     'azureml-model-group': 'REDACTED'
#     'x-envoy-upstream-service-time': 'REDACTED'
#     'x-ms-client-request-id': '4db6e510-bee6-43a7-882d-8ef1bdfe44fe'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'x-ratelimit-remaining-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:39:27 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3487'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '9b07fe24-00c0-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'request-context': 'REDACTED'
#     'prompt_token_len': 'REDACTED'
#     'sampling_token_len': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:39:35 GMT'
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '1869e19c-b125-4460-af72-28d875008dd1', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '01daa77c-8745-4e40-b622-b1f8ba3aeb1c', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '43e2c355-e5e9-417a-8f45-35371b941654', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:No. of sources with metadata: 3
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '1869e19c-b125-4460-af72-28d875008dd1', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '01daa77c-8745-4e40-b622-b1f8ba3aeb1c', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '43e2c355-e5e9-417a-8f45-35371b941654', '_collection_name': 'work_instructions_RAG'}
# ================================================================================
# Processing Query: How do I handle hypophosphorous acid?
# ================================================================================
# Final Answer: To handle hypophosphorous acid, follow these steps:
# * **Loading Process:**
# 1. Open manual valve 1 for loading 50% hypophosphorous acid, located above R-001.
# 2. Ensure the reactor is under vacuum.
# 3. Remove the cap from the acid container and insert Cane A.
# * **Container Management:**
# 1. If the container is empty, place it in the exit area.
# 2. From the entry area, take a new container and place it on the scale.
# 3. The field operator is responsible for collecting empty containers and ensuring a spare container is available in the entry area.
# Confidence: 95%
# Confidence: 95 %
# Source Documents Metadata:
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: 1869e19c-b125-4460-af72-28d875008dd1
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: 01daa77c-8745-4e40-b622-b1f8ba3aeb1c
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: 43e2c355-e5e9-417a-8f45-35371b941654
# _collection_name: work_instructions_RAG
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/work_instructions_RAG/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/work_instructions_RAG/points/search "HTTP/1.1 200 OK"
# INFO:query_engine:Retrieved document content: Deliver the sample to the control laboratory along with the analysis
# 8 report. Wait for the quality OK before starting the unloading process. Driver: Using a lifeline, harness, and safety guardrail, open the bottom valve. 9
# Open the tanker outlet valve and the manual line valve. Select the unloading tank and request plant authorization. Start the pump. 10
# During unloading, the driver must remain outside the cab and in view. Check and complete tanker documentation. Monitor for leaks and tank leve
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'b05e1a55-3d19-4ab1-a862-e005d6b6666e', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: Chock and signal it.'}, {'1': '5', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Ensure the tanker is sealed.\nDriver: Climb with a harness, lifeline, and raised guardrail to open the hatches and\ntop port. For SD-06, SD-07, and SD-12, take a sample from the top port using the\ndedicated tool.
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '8d7a9fc6-9b9e-48df-a442-74a359b341d8', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'At the end of unloading, verify complete tanker emptying.\nDriver: Using a harness, lifeline, and guardrail, close the bottom valve, hatches,\nand tanker outlet valve.'}, {'8': '13', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece.
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '2341da77-d899-4098-bc94-272f504583ae', '_collection_name': 'work_instructions_RAG'}
# WARNING:query_engine:Error calculating LLM relevance score: could not convert string to float: '2\n\nThe provided document excerpt does not directly address the specific safety measures required for unloading a tanker, which is one aspect of the query. It also does not specify which entities are responsible for ensuring these safety measures or when such measures should be implemented. Therefore, it is only somewhat relevant and not directly answering the specific sub-queries posed.'
# WARNING:query_engine:Error calculating LLM relevance score: could not convert string to float: '2\n\nThe provided document excerpt does not directly address safety measures for unloading a tanker, entities responsible for ensuring these measures, or when such measures should be implemented. It mentions some actions taken at the end of the process but lacks comprehensive information relevant to the specific queries posed.'
# WARNING:query_engine:Error calculating LLM relevance score: could not convert string to float: '3\n\nThe document excerpt provided does not directly address the specific safety measures required for unloading a tanker, which is part of the first sub-query. It also does not specify which entities are responsible for ensuring these safety measures or when they should be implemented, addressing the other two sub-queries. Therefore, while it contains some relevant information, it is not highly relevant to the full query.'
# WARNING:query_engine:Error calculating LLM relevance score: could not convert string to float: '2\n\nThe provided document excerpt does not directly address the specific safety measures required for unloading a tanker, which is one aspect of the query. It also does not specify which entities are responsible for ensuring these safety measures or when such measures should be implemented. Therefore, it is only partially relevant to the query and receives a low relevance score.'
# INFO:query_engine:Retrieved document content: Deliver the sample to the control laboratory along with the analysis\nreport.\nWait for the quality OK before starting the unloading process.': 'At the end of unloading, verify complete tanker emptying.\nDriver: Using a harness, lifeline, and guardrail, close the bottom valve, hatches,\nand tanker outlet valve.'}, {'8': '13', 'For SD-05 and SD-08, open the bottom valve of the tanker and take a sample from\nthe piece.
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'f7d48579-1991-491a-ad3d-fbcb07ab0fa6', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Specific PPE for Operator and Driver:\n• SD-05, SD-06, and SD-08: Neoprene gloves and face shield for helmet.\n• SD-07 and SD-12: Neoprene gloves, face shield for helmet, and apron.'}, {'1': '4', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Position the tanker in the designated area.
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'd62a7193-568e-49f9-af3b-7cb13611cb6f', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Retrieved document content: 3
# [Publish Date]
# [Comments]
#
# STRUCTURED TABLE DATA: [[['Work Instruction\nDocument Code: ZF-IT-CIS-25\nDate : 10/11/2020\nVersion: 3', 'Tanker Unloading to SD-05, SD-06,\nSD-07, SD-08, and SD-12']], [{'1': '2', 'Check and complete the tanker documentation. Verify the unloading order details:\nunloading tank, product, and correct level for unloading.': 'Open the steam passage valves to heat the pipes and installations.'}, {'1': '3', 'Check and complete the tanker documentation.
# INFO:query_engine:Retrieved document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '73042ed0-6329-457d-91f6-09ce74e02905', '_collection_name': 'work_instructions_RAG'}
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '416f267a-00c1-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'cfb6e394-ed2f-4eb5-bd82-3fd96180bd3d'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 1AB0994647684A27967C20E549EEF9C7 Ref B: VIEEDGE2416 Ref C: 2025-03-14T10:44:09Z'
#     'Date': 'Fri, 14 Mar 2025 10:44:08 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '42d4b2a0-00c1-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'b1388b8b-5e99-44a7-848d-57ac0e75f947'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: BE1A3477F727475C81BAB62A51D077BD Ref B: VIEEDGE2416 Ref C: 2025-03-14T10:44:09Z'
#     'Date': 'Fri, 14 Mar 2025 10:44:09 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3124'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '433b817e-00c1-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '1673'
#     'Content-Type': 'application/json'
#     'azureml-internal-engineid': 'REDACTED'
#     'azureml-model-id': 'REDACTED'
#     'openai-internal-encoding': 'REDACTED'
#     'openai-internal-engine-tags': 'REDACTED'
#     'openai-internal-engine-weight': 'REDACTED'
#     'openai-internal-sampling-args': 'REDACTED'
#     'openai-model': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'x-accel-buffering': 'REDACTED'
#     'x-ms-rai-invoked': 'REDACTED'
#     'x-request-id': 'REDACTED'
#     'azureml-destination-model-group': 'REDACTED'
#     'azureml-destination-region': 'REDACTED'
#     'azureml-destination-deployment': 'REDACTED'
#     'azureml-destination-endpoint': 'REDACTED'
#     'azureml-model-deployment': 'REDACTED'
#     'azureml-model-session': 'REDACTED'
#     'azureml-model-group': 'REDACTED'
#     'x-envoy-upstream-service-time': 'REDACTED'
#     'x-ms-client-request-id': '1ed74367-75bf-45fc-a6e7-f664bd68b3c9'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'x-ratelimit-remaining-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:44:18 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3118'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '4824b14c-00c1-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'request-context': 'REDACTED'
#     'prompt_token_len': 'REDACTED'
#     'sampling_token_len': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:44:22 GMT'
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'f7d48579-1991-491a-ad3d-fbcb07ab0fa6', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'd62a7193-568e-49f9-af3b-7cb13611cb6f', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '73042ed0-6329-457d-91f6-09ce74e02905', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'b05e1a55-3d19-4ab1-a862-e005d6b6666e', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '8d7a9fc6-9b9e-48df-a442-74a359b341d8', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:No. of sources with metadata: 5
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'f7d48579-1991-491a-ad3d-fbcb07ab0fa6', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': 'd62a7193-568e-49f9-af3b-7cb13611cb6f', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250207084523+01'00'", 'modDate': "D:20250207084523+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Tanker Unloading to SD-5, SD-6, SD-7, SD-8 and SD-12-1', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250207084523+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '3', 'Date': '10/11/2020', '_id': '73042ed0-6329-457d-91f6-09ce74e02905', '_collection_name': 'work_instructions_RAG'}
# ...
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '1a98e741-398c-4f36-bade-9fb839091565'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 68EA9146A36D4F51BEB47DF766C442EC Ref B: VIEEDGE3305 Ref C: 2025-03-14T10:57:26Z'
#     'Date': 'Fri, 14 Mar 2025 10:57:26 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1dcb5b9c-00c3-11f0-a4e6-38fc98f12ce6'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'cbaeff75-9f50-4cb2-81e1-015301d3389b'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 93E9C9A30CAD4D2F92FC2F96056EB0F6 Ref B: VIEEDGE3305 Ref C: 2025-03-14T10:57:26Z'
#     'Date': 'Fri, 14 Mar 2025 10:57:26 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '2906'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1e0fa054-00c3-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '960'
#     'Content-Type': 'application/json'
#     'azureml-internal-engineid': 'REDACTED'
#     'azureml-model-id': 'REDACTED'
#     'openai-internal-encoding': 'REDACTED'
#     'openai-internal-engine-tags': 'REDACTED'
#     'openai-internal-engine-weight': 'REDACTED'
#     'openai-internal-sampling-args': 'REDACTED'
#     'openai-model': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'x-accel-buffering': 'REDACTED'
#     'x-ms-rai-invoked': 'REDACTED'
#     'x-request-id': 'REDACTED'
#     'azureml-destination-model-group': 'REDACTED'
#     'azureml-destination-region': 'REDACTED'
#     'azureml-destination-deployment': 'REDACTED'
#     'azureml-destination-endpoint': 'REDACTED'
#     'azureml-model-deployment': 'REDACTED'
#     'azureml-model-session': 'REDACTED'
#     'azureml-model-group': 'REDACTED'
#     'x-envoy-upstream-service-time': 'REDACTED'
#     'x-ms-client-request-id': '9bf589a0-6205-43f2-8351-524962a2891f'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'x-ratelimit-remaining-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:57:29 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '2900'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1f7d687c-00c3-11f0-a4e6-38fc98f12ce6'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b8 Python/3.12.0 (Linux-6.12.18-1-lts-x86_64-with-glibc2.41)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'request-context': 'REDACTED'
#     'prompt_token_len': 'REDACTED'
#     'sampling_token_len': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Fri, 14 Mar 2025 10:57:32 GMT'
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': 'dc293ee1-4c41-481b-a387-d94ec1efb0f0', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '1fdc97e4-67b0-427a-a05a-85ecc61c91e5', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '87356d35-0dc4-44a0-85d3-d2b0354edf83', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250206231231+01'00'", 'modDate': "D:20250206231231+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Sulfated Analysis by HPLC', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250206231231+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '1', 'Date': '31/7/2020', '_id': '228febd0-e070-4771-8d37-33c35b259460', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Deduplicated document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250206231231+01'00'", 'modDate': "D:20250206231231+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Sulfated Analysis by HPLC', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250206231231+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '1', 'Date': '31/7/2020', '_id': '5ccc1f27-9c17-4536-956a-113d4578a92b', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:No. of sources with metadata: 5
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': 'dc293ee1-4c41-481b-a387-d94ec1efb0f0', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '1fdc97e4-67b0-427a-a05a-85ecc61c91e5', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250204224823+01'00'", 'modDate': "D:20250204224823+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Hypophosphorous Acid', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250204224823+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '2', 'Date': '20/06/2020', '_id': '87356d35-0dc4-44a0-85d3-d2b0354edf83', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250206231231+01'00'", 'modDate': "D:20250206231231+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Sulfated Analysis by HPLC', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250206231231+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '1', 'Date': '31/7/2020', '_id': '228febd0-e070-4771-8d37-33c35b259460', '_collection_name': 'work_instructions_RAG'}
# INFO:query_engine:Final document metadata: {'format': 'PDF 1.7', 'title': '', 'author': 'Ricard Torralba', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word for Microsoft 365', 'producer': 'Microsoft® Word for Microsoft 365', 'creationDate': "D:20250206231231+01'00'", 'modDate': "D:20250206231231+01'00'", 'trapped': '', 'encryption': None, 'Document Name': 'Work Instruction - Sulfated Analysis by HPLC', 'Step Number': None, 'Author': 'Ricard Torralba', 'Created Date': "D:20250206231231+01'00'", 'Keywords': [''], 'Process Type': None, 'Safety Measures': [], 'Version': '1', 'Date': '31/7/2020', '_id': '5ccc1f27-9c17-4536-956a-113d4578a92b', '_collection_name': 'work_instructions_RAG'}
# ================================================================================
# Processing Query: What is the required PPE for handling sulfuric acid?
# ================================================================================
# Final Answer: * Required PPE for handling sulfuric acid includes:
# + Neoprene gloves
# + Face shield
# + Apron
# Confidence: 100%
# Confidence: 100 %
# Source Documents Metadata:
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: dc293ee1-4c41-481b-a387-d94ec1efb0f0
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: 1fdc97e4-67b0-427a-a05a-85ecc61c91e5
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250204224823+01'00'
# modDate: D:20250204224823+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Hypophosphorous Acid
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250204224823+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 2
# Date: 20/06/2020
# _id: 87356d35-0dc4-44a0-85d3-d2b0354edf83
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250206231231+01'00'
# modDate: D:20250206231231+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Sulfated Analysis by HPLC
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250206231231+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 1
# Date: 31/7/2020
# _id: 228febd0-e070-4771-8d37-33c35b259460
# _collection_name: work_instructions_RAG
# ----------------------------------------
# format: PDF 1.7
# title:
# author: Ricard Torralba
# subject:
# keywords:
# creator: Microsoft® Word for Microsoft 365
# producer: Microsoft® Word for Microsoft 365
# creationDate: D:20250206231231+01'00'
# modDate: D:20250206231231+01'00'
# trapped:
# encryption: None
# Document Name: Work Instruction - Sulfated Analysis by HPLC
# Step Number: None
# Author: Ricard Torralba
# Created Date: D:20250206231231+01'00'
# Keywords: ['']
# Process Type: None
# Safety Measures: []
# Version: 1
# Date: 31/7/2020
# _id: 5ccc1f27-9c17-4536-956a-113d4578a92b
# _collection_name: work_instructions_RAG
