# %% [markdown]
# ## Step 3 Validation: Query Engine Multi-Stage QA with Intermediate Outputs
# This notebook validates the multi-stage QA process and prints intermediate outputs:
#  1. Query decomposition (sub-queries).
#  2. Retrieval of documents for each sub-query.
#  3. Synthesis of the final answer.
#  4. Final summary with confidence rating.
#
# The process uses LangSmith's Client for tracing, and the retriever benefits from earlier reranking.

# %%
import logging

from langsmith import Client, traceable

from config import RESOURCES_PATH
from document_loader import load_sop_documents
from llm import get_llm
from query_engine import QueryEngine, QueryResult
from query_engine import search_tables_for_answer
from retriever import setup_sop_retriever
from text_processing import dynamic_text_splitter

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Initialize LangSmith Client for tracing.
client = Client()

# %%
@traceable(project_name="sop_validation", client=client)
def validate_query_processing(user_query: str, retriever_instance) -> QueryResult:
    """
    Validates query processing by searching both document text and structured table data.
    """
    # Instantiate the QueryEngine with structured table integration.
    query_engine_instance = QueryEngine(debug_mode=True, confidence_threshold=80)

    # Execute the query on unstructured text.
    result = query_engine_instance.query_documents_advanced(user_query, retriever_instance)

    # Initialize an empty table context to avoid UnboundLocalError
    table_context = ""

    # Extract structured tables from retrieved documents (only if metadata is available)
    table_results = []
    if result.source_documents:
        for doc in result.source_documents:
            if "tables" in doc:
                table_results.extend(search_tables_for_answer([doc], user_query))

    # If table results are found, integrate them into the final response.
    if table_results:
        table_context += "\nRelevant Table Data:\n"
        for doc_name, matches in table_results:
            table_context += f"\nDocument: {doc_name}\n"
            for param, value in matches:
                table_context += f"{param}: {value}\n"

    # Append structured table results to the LLM-generated answer, only if table_context is not empty
    if table_context:
        result.answer += f"\n\n{table_context}"

    return result

# %%
# Load SOP documents and split into chunks.
documents = load_sop_documents(RESOURCES_PATH)
document_chunks = dynamic_text_splitter(documents, default_chunk_size=500)
print(f"Loaded {len(documents)} document(s) and created {len(document_chunks)} chunks.")
# Out:
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 6 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 9 Date: 08/02/2021 | CONFIDENTIAL PRODUCT: ALKYLBENZEN SULFONIC ACID (11027563)
#
# [MATCH] Found Review: 9
# [MATCH] Found Date: 08/02/2021
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | SULFAX |  |  |
# REACTOR : | R503 |  |  |
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302- Harmful if swallowed. H314-Causes severe skin burns and serious eye damage. | H302- Harmful if swallowed. H314-Causes severe skin burns and serious eye damage. | H302- Harmful if swallowed. H314-Causes severe skin burns and serious eye damage.
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS
# 50386977 | LINEAR ALKYLBENZENE H304- May be fatal if swallowed and enters airways | LINEAR ALKYLBENZENE H304- May be fatal if swallowed and enters airways |  | 750
# 50087496 | LIQUID SULFUR H315- Causes skin irritation. | LIQUID SULFUR H315- Causes skin irritation. |  | 110
# 50059005 | SODIUM HYDROXIDE 30% H318- Causes severe skin burns and eye damage. H290 – May be corrosive to metals | SODIUM HYDROXIDE 30% H318- Causes severe skin burns and eye damage. H290 – May be corrosive to metals |  | 1
# 50197449 | WATER | WATER |  | 8
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# Raw Material Loading
# 1. Check Raw Materials
# 2. Prepare “Day Tank 24.2” from SM-08.
# 3. Prepare the destination for "DDBS" (without passing through the maturator): Consult the Shift Supervisor.
# 4. Check parameters according to the desired performance.
# 5. Ensure that the outlet valve of DT24.2 is open and set the previously consulted organic weight in the R-503 screen.
# 6. Start circulating dodecylbenzene through the reactor at the desired flow rate and activate cooling.
# 7. Begin sulfonation with the following conditions:
# 8. Modify gas splitting conditions if required
# When there is a visible chance in the ester acid drop in the reactor, send the output from the tank into the maturing device.
# Check acidic index and ester acid colour. If they are both correct, send the “DDBS” through the maturing equipment to the desired endpoint. If Acidic index is not correct, modify base flow in the reactor using the following formula: Actual Acidity Index * Base Kg = Desired Acidity Index * Kgs Base
# Add the required amount of wáter and send the liquid to the target tank
# Take a sample at the exit of the “DDBS” maturing device and analyse with Near Infrared
# Purge oleum once a day and clean tanks 1 and 2
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
#  | METHOD NR | VALUE
# Acidic Index | 8018 | 180-185 mg KOH/g
# Anionic Mass | 8049 | 96-98%
# Humidity | 8227 | 0.5-2%
# Sulfonates | 8400 | 0-2%
# ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS
# Waste Management: Sample waste is recoverable within the same production fabrication Wastewater Generation: None. | Waste Management: Sample waste is recoverable within the same production fabrication Wastewater Generation: None. | Waste Management: Sample waste is recoverable within the same production fabrication Wastewater Generation: None.
#
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 6 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 24 Date: 24/04/2021 | CONFIDENTIAL PRODUCTO: AN-84 (10939987)
#
# [MATCH] Found Review: 24
# [MATCH] Found Date: 24/04/2021
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | POLISAL3 |  |  |
# REACTOR : | R003 | R002 |  |
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms.
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS/TM
# 50386977 | RDB Palm Kernel Oil | RDB Palm Kernel Oil |  | 690
# 50082832 | DIMETHYLAMINOPROPYLAMINE BULK + DIMETHYLAMINOPROPYLAMINE REC. H314 Causes severe skin burns and eye damage H311 Toxic in contact with skin. H331 Toxic if inhaled. H302 Harmful if swallowed. H317 May cause an allergic skin reaction. H226 Flammable liquid and vapor. | DIMETHYLAMINOPROPYLAMINE BULK + DIMETHYLAMINOPROPYLAMINE REC. H314 Causes severe skin burns and eye damage H311 Toxic in contact with skin. H331 Toxic if inhaled. H302 Harmful if swallowed. H317 May cause an allergic skin reaction. H226 Flammable liquid and vapor. |  | 378
# 10966709 | CATALYST AN-84 | CATALYST AN-84 |  | 5,6
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# Loading Raw Materials | Loading Raw Materials
# 1. Load all raw materials simultaneously. Load Palm Kernel Oil Load Catalyst AN-84. Load Recovered DAPA Load Fresh DAPA Load all the recovered DAPA from the distillate tanks and the necessary amount of new DAPA to reach the specified quantity. | (R003 / R002) (R003 / R002) (R003 / R002) (R003 / R002)
# 2. Begin recirculation and agitation. Maintain until the process is complete. Do not wait for the full load to be completed. Start recirculation once 2000 kg have been added. | (R003 / R002)
# 3. Heat to 170ºC immediately and maintain until otherwise instructed. Do not wait for the load to finish. | (R003 / R002)
# 4. Close the vent valve to operate under pressure. | (R003 / R002)
# Amidation Reaction | Amidation Reaction
# 5. Maintain 170°C for 3 hours Monitor that pressure does not exceed 2500 mBar (safety valve triggers at 4000 mBar). |
# 6. Take a sample Analyze Ester Band (Analysis Method 8007). If Ester Band > 0.4, maintain conditions for 30 min and take another sample. If after 1 hour the value remains high, check the loads (possible excess DAPA). If Ester Band < 0,4 OK | (R003 / R002)
# Distillation | Distillation
# 7. Manage distillation process | (R003 / R002)
# 8. Lower heating setpoint to 165ºC to avoid material carryover during distillation | (R003 / R002)
# 9. Apply vacuum to reach 500 mBar within 10 minutes. | (R003 / R002)
# 10. Reduce vacuum from 500 to 200 mBar within 40 minutes (DAPA will begin distilling). | (R003 / R002)
# 11. Further reduce vacuum from 200 to 10 mBar within 60 minutes (DAPA distillation continues). | (R003 / R002)
# 12. At P=15mBar, take a sample Analyze Amine Index (Analysis Method 8001). If AI > 163 Retest every 30 minutes. If after 2 hours the value remains above 163, apply vacuum (10 mBar in 30 min) and notify the Shift Supervisor. If AI < 163 Proceed If the amine index value increases, it is because glycerin is being distilled (which, due to the concentration effect, causes the amine index to rise) → Consider point 10 as completed. | (R003 / R002) (R003 / R002)
# 13. Cool the reactor by setting the heat exchanger outlet temperature to 80ºC. | (R003 / R002)
# 14. At 80ºC, begin transfer with a light nitrogen flow. | (R003 / R002)
# 15. Purge all lines with nitrogen multiple times. | (R003 / R002)
# 16. Close transfer valves and stop cooling pump. |
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
# PARAMETER | METHOD NR | VALUE
# Aspect Amine Index Ester Band | 8000 8001 8007 | Blue Liquid 160-163 < 0,4
# t | t | t
# Waste Management: Recovered DAPA is reused. Sample residues can be used in subsequent AN-84 batches. Empty product bags must be destroyed as RES-34 waste. Wastewater Generation: Vacuum pump discharge during distillation contains more than 98% water. | Waste Management: Recovered DAPA is reused. Sample residues can be used in subsequent AN-84 batches. Empty product bags must be destroyed as RES-34 waste. Wastewater Generation: Vacuum pump discharge during distillation contains more than 98% water. | Waste Management: Recovered DAPA is reused. Sample residues can be used in subsequent AN-84 batches. Empty product bags must be destroyed as RES-34 waste. Wastewater Generation: Vacuum pump discharge during distillation contains more than 98% water.
#
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 6 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 16 Date: 24/01/2024 | CONFIDENTIAL PRODUCT: AS-42 (11027563)
#
# [MATCH] Found Review: 16
# [MATCH] Found Date: 24/01/2024
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | POLISAL 4 |  |  |  |
# REACTOR : | R002 |  |  |  |
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: |  | H314- Causes severe skin burns and serious eye damage. | H314- Causes severe skin burns and serious eye damage. | H314- Causes severe skin burns and serious eye damage.
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS/Tn
# 50386977 | EDENOR HK 8-18 H315- Causes skin irritation. H318- Causes serious eye damage. | EDENOR HK 8-18 H315- Causes skin irritation. H318- Causes serious eye damage. | EDENOR HK 8-18 H315- Causes skin irritation. H318- Causes serious eye damage. |  | 690
# 50087496 | BULK AMINOETILETHANOLAMINA H314- Causes severe skin burns and serious eye damage. H317- May cause allergic reaction on the skin | BULK AMINOETILETHANOLAMINA H314- Causes severe skin burns and serious eye damage. H317- May cause allergic reaction on the skin | BULK AMINOETILETHANOLAMINA H314- Causes severe skin burns and serious eye damage. H317- May cause allergic reaction on the skin |  | 454
# 50059005 | HYPOPHOSPHOROUS ACID 50% H314- Causes severe skin burns and serious eye damage. | HYPOPHOSPHOROUS ACID 50% H314- Causes severe skin burns and serious eye damage. | HYPOPHOSPHOROUS ACID 50% H314- Causes severe skin burns and serious eye damage. |  | 1.1
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# Raw Material Loading
# 1. Load Edenor HK 8-18
# 2. Open the manual valve for condensate flow from the deflagmator to the column and close the manual valve toward reflux.
# Esterification Reaction
# 3. Close vent and apply vacuum at P=800mBar in 0 seconds.
# 4. Load hypophosphorous acid into R002 reactor. Use PPE, as phosphine (toxic and flammable) can be generated
# 5. Break vacuum with nitrogen until reaching a pressure of 1050 mBar in 0 seconds.
# 6. Check the temperature If T < 100 ºC 🡪 OK If T > 100 ºC 🡪Cool down with a temperature setpoint of 90 ºC Reaction is exothermic.
# 7. Load Aminoethanolamina (AEEA) from collector B
# 8. Close the manual valve for the thermic oil entrance
# 9. Heat the reactor using the jacket. Setpoint TI-013 = 180ºC in 0s. Maintain until otherwise indicated. (R002)
# 10. Distillate management
# 11. At T=180ºC, drain the water from the distillate collectors into the pit.
# 12. Start heating via FAFFI: Stop the oil pump. Open the manual valve for oil inlet to FAFFI Begin product recirculation Heat reactor by setting the temperature to the lower evaporator at T = 180 ºC (R002)
# 13. Apply vacuum in 3 ramps: P = 600mBar at t = 0 P = 200mBar at t = 1h P = 50mBar at t = 3h (R002)
# 14. Maintain for 1 hour between 180-185ºC at P = 50mBar.
# 15. Take a sample. Analyze reaction absorbance via IR (Analysis method 8422). If IR < 0.2 OK If IR > 0.2 Increase temperatura to 185 ºC and take samples every hour until IR is correct. If the distillate collector fills up, empty it into the wastewater collector. (R002)
# Esterification Reaction
# 16. Drain distillate tanks into the pit.
# 17. Distillate Management Table Close reflux valve to the column. To change the control TAG, the pump must be stopped beforehand. (R002)
# 18. Apply vacuum, P=4mBar in 0 seconds. AEEA distillation will be observed
# 19. Wait 3 hours. Take a sample. Analyze nitrogen content (Analysis method 8001) If N < 5% 🡪 OK If N > 5%: Heat to 190 ºC while maintaining vacuum Take a sample and analyze nitrogen content every hour.
# 20. Cool to 80-90ºC while maintaining vacuum.
# 21. Break vacuum and regulate P=1000mBar with nitrogen.
# 22. Transfer to reactor R-33.
# 23. Purge all lines with nitrogen multiple times.
# 24. Load 2 Tons of water, recirculate through heat exchangers, and send to R-33
# 25. Purge all lines with nitrogen.
# 26. Close transfer valves and stop the cooling pump.
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
#  | METHOD NR | VALUE
# Appearence | 8000 | Yellow liquid
# IR | 8422 | < 0.2
# Nitrogen | 8001 | < 5
# ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS
# Waste Management: AEEA + water for recycling through distillation as recovered AEEA. AEEA REC to be reused as is in AV-12. Wastewater Generation: Water + amine from distillation with water content above 90%, approximately 1000 kg. | Waste Management: AEEA + water for recycling through distillation as recovered AEEA. AEEA REC to be reused as is in AV-12. Wastewater Generation: Water + amine from distillation with water content above 90%, approximately 1000 kg. | Waste Management: AEEA + water for recycling through distillation as recovered AEEA. AEEA REC to be reused as is in AV-12. Wastewater Generation: Water + amine from distillation with water content above 90%, approximately 1000 kg.
#
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 7 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 2 Date: 23/1/2024 | CONFIDENTIAL PRODUCT: FAES (11173126)
#
# [MATCH] Found Review: 2
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | SULFAX |  |  |
# REACTOR : | R02 |  |  |
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | NONE | NONE | NONE
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS
# 50201825 | DEHYDOL LS30 H319 - Causes serious eye irritation. | DEHYDOL LS30 H319 - Causes serious eye irritation. |  | 304
# 50197102 | LIQUID SULFUR H315 - Causes skin irritation. | LIQUID SULFUR H315 - Causes skin irritation. |  | 6,87
# 50200623 | SODIUM HYDROXIDE 50% H290 May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. | SODIUM HYDROXIDE 50% H290 May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. |  | 18,2
# 50565738 | AOCOSM 30% H271 – Very comburent. H302- Harmful if swallowed. H332 – Harmful if ingested. | AOCOSM 30% H271 – Very comburent. H302- Harmful if swallowed. H332 – Harmful if ingested. |  | 0,15
# 50714486 | SULFURIC ACID 60% H314- Causes severe skin burns and serious eye damage. | SULFURIC ACID 60% H314- Causes severe skin burns and serious eye damage. |  | 0,2
# 10942110 | PEG4000 SOLUTION 50% | PEG4000 SOLUTION 50% |  | 33
# 50198740 | SODIUM HYDROXIDE 30% H290 May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. | SODIUM HYDROXIDE 30% H290 May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. |  | 0,5
# 52407449 | ACTICIDE MBS 2550 H302- Harmful if swallowed. H317 – May cause an allergic skin reaction. H331 – Toxic if inhaled H400 - Very toxic to aquatic organisms. | ACTICIDE MBS 2550 H302- Harmful if swallowed. H317 – May cause an allergic skin reaction. H331 – Toxic if inhaled H400 - Very toxic to aquatic organisms. |  | 3
# 50832668 | ACTICIDE SPX 30KG DRUM H318- Causes serious eye damage. H314- Causes severe skin burns and serious eye damage. H317 – May cause an allergic skin reaction H400 - Very toxic to aquatic organisms. H411 – Toxic to aquatic life with long-lasting effects | ACTICIDE SPX 30KG DRUM H318- Causes serious eye damage. H314- Causes severe skin burns and serious eye damage. H317 – May cause an allergic skin reaction H400 - Very toxic to aquatic organisms. H411 – Toxic to aquatic life with long-lasting effects |  | 2
# 50197449 | WATER | WATER |  | 610
# 11007697 | SODIUM BICARBONATE SOLUTION 7.5% | SODIUM BICARBONATE SOLUTION 7.5% |  | 12
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# Parameter | Setpoint | Remarks
# Reactor cooling wáter setpoint | 60 ºC | When sulfation starts, switch reactor jacket from heating to cooling.
# Reactor head gas temp. | 35-45 ºC | Use dilution air.
# Base temperature | 60 ºC |
# SO3 second cooler exit temp. | 85 ºC | "SO3 Generation" TIC-21.7B
# Sulfur flow rate | 65 Kg/h |
# SO3 concentration in R2 | 3,54 % |
# Dehydol LS30 | 2640 Kg/h |
# Osmotized water | 5300 Kg/h |
# Sodium hydroxide 50% | 105-115 L/h | Adjust according to pH.
# PEG4000 Solution 50% | 280 Kg/h |
# Fryma flow rate regulation | 100 % | Manual mode
# Fryma pressure regulation | 80% | Manual mode. Check section 7.
# Vacuum in Fryma | -0,95 Barg |
# Steam to Fryma | 32% | Open valve manually when product passes.
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# Parameter | Aditivo
# Flow Point | PEG4000 Solution 50%
# Apha Color | Hydrogen Peroxide 35%
# pH | Sodium Hydroxide 30% or Sulfuric Acid 60%
# Dry Residue | Water
#
# [DEBUG] Processing Table 7
#
# [DEBUG] Table 7 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
#  | METHOD NR | VALUE
# Acid Index | 8018 | 42-43 mg KOH/g
# Active Matter (PM102) | 8049 | 2,20-2,40 %
# pH (10%) | 8227 | 8,0-8,5
# Dioxane | 8485 | <150 ppm
# Color Apha (before preservatives) | 8238 | <100
# Flow Point |  | -4ºC to +5ºC
# Dry Residue | 8932 | 32-34 %
# Oxidizing Power | 8877 | 0-1 ppm
# Reducing Power (test stripsI | 8728 | None
# Sulfates | 9126 | < 2%
# ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS
# Waste Management: S ample containers recoverable in the same batch. Packaging waste returned to the supplier or recycled. | Waste Management: S ample containers recoverable in the same batch. Packaging waste returned to the supplier or recycled. | Waste Management: S ample containers recoverable in the same batch. Packaging waste returned to the supplier or recycled.
#
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 6 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 22 Date: 08/04/2023 | CONFIDENTIAL PRODUCT: TEXAPON S80 (10937317)
#
# [MATCH] Found Review: 22
# [MATCH] Found Date: 08/04/2023
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | SULFAX |  |  |
# REACTOR : | R01 | R02 | R03 | R04
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H315- Causes skin irritation. H318- Causes serious eye damage. | H315- Causes skin irritation. H318- Causes serious eye damage. | H315- Causes skin irritation. H318- Causes serious eye damage.
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS
# 50200545 | DEHYDOL LS 2HN H412- Harmful for aquatic organisms, with long term toxic effects H400- Very toxic for aquatic organisms | DEHYDOL LS 2HN H412- Harmful for aquatic organisms, with long term toxic effects H400- Very toxic for aquatic organisms |  | 512
# 50197102 | LIQUID AZUFRE H315- Causes skin irritation. | LIQUID AZUFRE H315- Causes skin irritation. |  | 71
# 50200623 | SODIUM METHYLATE 30% H290- May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. | SODIUM METHYLATE 30% H290- May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. |  | 213
# 50565738 | AOCOSM 30% H318- Causes serious eye damage. H302- Harmful if swallowed. H373- May cause organ damage with prolonged or repeated exposure. | AOCOSM 30% H318- Causes serious eye damage. H302- Harmful if swallowed. H373- May cause organ damage with prolonged or repeated exposure. |  | 0.5
# 10942090 | SODIUM BISULFITE H271 – Very comburent H332 – Harmful if inhaled H302- Harmful if swallowed. | SODIUM BISULFITE H271 – Very comburent H332 – Harmful if inhaled H302- Harmful if swallowed. |  | 15.6
# 50198380 | SODIUM BISULFITE H302- Harmful if swallowed. | SODIUM BISULFITE H302- Harmful if swallowed. |  | 0.5
# 50197449 | WATER | WATER |  | 210
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# 1. Check that there is enough raw material.
# 2. Apply vacuum. P=50 mBar if necessary to ensure the entire system is dry.
# 3. Stop the vacuum pump and break the vacuum with nitrogen.
# 4. Load the palm kernel oil.
# 5. Apply a light nitrogen flow from the bottom.
# 6. Heat to 65ºC using the jacket.
# 7. Recirculate and take a sample for moisture analysis. Analyze water content (Analysis Method 8227). If water content > 0,2% Drying required. Apply vacuum P=50mBar in 0 seconds and heat to 85ºC using the jacket. Maintain conditions for 2 hours and repeat the analysis.
# 8. Load the Diethanolamine.
# 9. Stop the nitrogen flow from the bottom and apply accumulated vacuum: 500mBar. It is important that the vacuum is accumulated to prevent methanol from Sodium Methylate 30% from remaining in the reactor.
# 10. At T=65ºC, load Sodium Methylate 30% using a membrane pump, ensuring no air enters the reactor (reaction catalyst). Apply a light nitrogen flow from the bottom and recirculate the product. An exothermic reaction will occur, reaching temperatures of 95-97ºC.
# 11. Wait 1 hour and cool the mixture to 75ºC. Take a sample and send it to the control lab to analyse free alkali, diethanolamine, and ester band. If parameters are correct 🡪 OK. If parameters are incorrect, make necessary adjustments: To reduce free diethanolamine, adjust with Palm Kernel Oil To lower the ester band, adjust with Diethanolamine. To adjust the alkali level, use Sodium Methylate 30%. Note: As the reaction progresses, diethanolamine and ester band values will decrease. Once the product is cooled, the ester band will continue decreasing slowly, while the diethanolamine value will hardly change. For proper adjustment, diethanolamine should be between 4.8-5.3 mg KOH/g, and the ester band should be between 8.5-9.5%, always with the presence of alkali.
# 12. Stop the nitrogen flow from the bottom.
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
#  | METHOD NR | VALUE
# Acidic Index | 8018 | 158-162 mg KOH/g
# Anionic MA (PM382) | 8049 | 68,2-68,6 %
# PH (3%) | 8227 | 7,5-8,5
# Insulphates | 8400 | 1,7-2,1 %
# Dioxane | 8455 | < 14 ppm
# Colour Alpha (20% water) | 8238 | 0-25
# Sodium sulphate | 8035 | 0-1 %
# Oxidation Power | 8728 | 1-5 meq/g
# ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS
# Waste Management: Sample containers recoverable within the same production. Packaging: adjustment-related waste to be returned to the supplier or recycled. Wastewater Generation: From the vacuum pump: clean water at a rate of 2000 L/h. From distillation in the neutralization circuit: 800-1400 L/h of water with a content of more than 99% water. | Waste Management: Sample containers recoverable within the same production. Packaging: adjustment-related waste to be returned to the supplier or recycled. Wastewater Generation: From the vacuum pump: clean water at a rate of 2000 L/h. From distillation in the neutralization circuit: 800-1400 L/h of water with a content of more than 99% water. | Waste Management: Sample containers recoverable within the same production. Packaging: adjustment-related waste to be returned to the supplier or recycled. Wastewater Generation: From the vacuum pump: clean water at a rate of 2000 L/h. From distillation in the neutralization circuit: 800-1400 L/h of water with a content of more than 99% water.
#
# [DEBUG] extract_metadata_from_docx() function started.
# [DEBUG] Found 6 tables in the document.
# [DEBUG] Processing Table 1
#
# [DEBUG] Table 1 Extracted Text:
# AG SOLUTION MANUFACTURING PROCEDURE Review: 13 Date: 08/02/2024 | CONFIDENTIAL PRODUCTO: TONPERLAN OCD (11027563)
#
# [MATCH] Found Review: 13
# [MATCH] Found Date: 08/02/2024
# [DEBUG] Processing Table 2
#
# [DEBUG] Table 2 Extracted Text:
# PLANT : | POLISAL 4 |  |  |
# REACTOR : | R002 |  |  |
#
# [DEBUG] Processing Table 3
#
# [DEBUG] Table 3 Extracted Text:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H315- Causes skin irritation. H318- Causes serious eye damage. | H315- Causes skin irritation. H318- Causes serious eye damage. | H315- Causes skin irritation. H318- Causes serious eye damage.
# MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE | MANUFACTURING PROCEDURE
# SAP CODE | DESCRIPTION | DESCRIPTION | P. | LOAD KILOS
# 50386977 | PALM KERNEL OIL RBD/MB kosher | PALM KERNEL OIL RBD/MB kosher |  | 681
# 50087496 | DIETHANOLAMINE H315- Causes skin irritation. H318- Causes serious eye damage. H302- Harmful if swallowed. H373- May cause organ damage with prolonged or repeated exposure. | DIETHANOLAMINE H315- Causes skin irritation. H318- Causes serious eye damage. H302- Harmful if swallowed. H373- May cause organ damage with prolonged or repeated exposure. |  | 322
# 50059005 | SODIUM METHYLATE 30% H226- Flammable liquid and vapors. H290- May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. H311- Toxic if inhaled. H331- Toxic if swallowed. H301- Tóxico en caso de ingestión H370- Causes damage to organs (central nervous system, optic nerve). | SODIUM METHYLATE 30% H226- Flammable liquid and vapors. H290- May be corrosive to metals. H314- Causes severe skin burns and serious eye damage. H311- Toxic if inhaled. H331- Toxic if swallowed. H301- Tóxico en caso de ingestión H370- Causes damage to organs (central nervous system, optic nerve). |  | 12
#
# [DEBUG] Processing Table 4
#
# [DEBUG] Table 4 Extracted Text:
# OPERATIONAL METHOD
#
# [DEBUG] Processing Table 5
#
# [DEBUG] Table 5 Extracted Text:
# Raw Material Loading
# 1. Check that there is enough raw material.
# 2. Apply vacuum. P=50 mBar if necessary to ensure the entire system is dry.
# 3. Stop the vacuum pump and break the vacuum with nitrogen.
# 4. Load the palm kernel oil.
# 5. Apply a light nitrogen flow from the bottom.
# 6. Heat to 65ºC using the jacket.
# 7. Recirculate and take a sample for moisture analysis. Analyze water content (Analysis Method 8227). If water content < 0.2% → OK. If water content > 0,2% Drying required. Apply vacuum P=50mBar in 0 seconds and heat to 85ºC using the jacket. Maintain conditions for 2 hours and repeat the analysis.
# 8. Load the Diethanolamine.
# 9. Stop the nitrogen flow from the bottom and apply accumulated vacuum: 500mBar. It is important that the vacuum is accumulated to prevent methanol from Sodium Methylate 30% from remaining in the reactor.
# 10. At T=65ºC, load Sodium Methylate 30% using a membrane pump, ensuring no air enters the reactor (reaction catalyst). Apply a light nitrogen flow from the bottom and recirculate the product. An exothermic reaction will occur, reaching temperatures of 95-97ºC.
# 11. Wait 1 hour and cool the mixture to 75ºC. Take a sample and send it to the control lab to analyse free alkali, diethanolamine, and ester band. If parameters are correct OK. If parameters are incorrect, make necessary adjustments: To reduce free diethanolamine, adjust with Palm Kernel Oil To lower the ester band, adjust with Diethanolamine. To adjust the alkali level, use Sodium Methylate 30%. Note: As the reaction progresses, diethanolamine and ester band values will decrease. Once the product is cooled, the ester band will continue decreasing slowly, while the diethanolamine value will hardly change. For proper adjustment, diethanolamine should be between 4.8-5.3 mg KOH/g, and the ester band should be between 8.5-9.5%, always with the presence of alkali.
# 12. Stop the nitrogen flow from the bottom.
# 13. Cool to 40ºC.
# 14. At T<45ºC, take a sample and send it to the control lab.
# 15. Transfer and purge.
# 16. Perform a short wash of the reactor and exchangers.
#
# [DEBUG] Processing Table 6
#
# [DEBUG] Table 6 Extracted Text:
# PROCESS CONTROL | PROCESS CONTROL | PROCESS CONTROL
#  | Nº MÉTODO | VALOR
# Appearence | 8000 | Yellow liquid
# Ester Band | 8007 | < 8%
# Free Diethanolamine | 8008 | < 5,0%
# Free Alkali | 8008 | < 0,3%
# ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS | ENVIRONMENTAL ASPECTS
# Waste Management: Packaging to be returned to the supplier for recycling. Sample waste is recoverable within the same production. Wastewater Generation: None. | Waste Management: Packaging to be returned to the supplier for recycling. Sample waste is recoverable within the same production. Wastewater Generation: None. | Waste Management: Packaging to be returned to the supplier for recycling. Sample waste is recoverable within the same production. Wastewater Generation: None.
#
# Loaded 6 document(s) and created 250 chunks.

# %%
# Choose the model for the Query Engine.
model_choice = "azure"  # Change to "ollama" or "qwen2.5" as needed.
llm_instance = get_llm(model_choice)
# Out:
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.3 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '917ee5b2-00c2-11f0-8d59-f09e4a618b6c'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.3 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '945b4efd-d987-4615-8c64-1b714bf90558'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: A0FB98EF8BD7414681FA00199ABF80F8 Ref B: VIEEDGE2210 Ref C: 2025-03-14T10:53:32Z'
#     'Date': 'Fri, 14 Mar 2025 10:53:32 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '923abc91-00c2-11f0-8c67-f09e4a618b6c'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.12.3 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '5b48776e-e587-4f2f-8275-7f3e6a9f762c'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 8D16D065D4CC4B21B4AF72986F1ABC80 Ref B: VIEEDGE2210 Ref C: 2025-03-14T10:53:32Z'
#     'Date': 'Fri, 14 Mar 2025 10:53:32 GMT'

# %%
# Set up the retriever from the SOP chunks.
retriever_instance = setup_sop_retriever(document_chunks)
queries = [
    # "When synthesizing Alkylbenzen sulfonic acid, which should be the setpoint for the sulfur trioxide when doing the sulfonation?",
    "Which range of humidity values are acceptable for the Alkylbenzen Sulfonic Acid?",
    "Describe the hazard classification of the AN-84 product.",
    # "Which are the raw materials used for the production of AS-42? How much of each raw material should be used for the production of 1 Ton of AS-42?"
]
# Out:
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1cae1cca-0314-11f0-8f3c-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '3e14c64f-7043-4ca3-bb4b-ed0e54870303'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 723F70B687944F48AB0088C92CBBBE51 Ref B: VIEEDGE3016 Ref C: 2025-03-17T09:42:18Z'
#     'Date': 'Mon, 17 Mar 2025 09:42:17 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1ebdeaea-0314-11f0-a5b9-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '59fa12d8-fefa-4998-9aa5-f0ba3d7aa3b8'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 531FC5C053DE4811B0FAEFC4C38141DD Ref B: VIEEDGE3016 Ref C: 2025-03-17T09:42:18Z'
#     'Date': 'Mon, 17 Mar 2025 09:42:18 GMT'
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [DEBUG] Adding 250 SOP documents to ChromaDB.
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"

# %%
# Display the final output with full metadata for each source document.
# Initialize the QueryEngine with debug mode for detailed output
for query in queries:
    query_result = validate_query_processing(query, retriever_instance)
    print("=" * 80)
    print(f"Processing Query: {query}")
    print("=" * 80)
    print("Final Answer:", query_result.answer)
    print("Confidence:", query_result.confidence, "%")
    print("Source Documents Metadata:")
    for source in query_result.source_documents:
        print("-" * 40)
        for key, value in source.items():
            print(f"{key}: {value}")
# Out:
# C:\Users\mnmhy\PycharmProjects\agenticrag\llm.py:80: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   self._ollama = Ollama(model=model, temperature=temperature)
# C:\Users\mnmhy\PycharmProjects\agenticrag\llm.py:87: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return self._ollama(prompt, stop=stop)
# C:\Users\mnmhy\PycharmProjects\agenticrag\query_engine.py:278: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = qa_chain_instance.retriever.get_relevant_documents(subq)
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:query_engine:Retrieved document content: METHOD NR                                                                                                                 VALUE
#                                                                                                          Acidic Index                                                                                                                  8018                                                                                                      180-185 mg KOH/g
#
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Retrieved document content: METHOD NR                                                                                                                 VALUE
#                                                                                                          Acidic Index                                                                                                                  8018                                                                                                      180-185 mg KOH/g
#
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Retrieved document content: METHOD NR                                                                                                                 VALUE
#                                                                                                          Acidic Index                                                                                                                  8018                                                                                                      180-185 mg KOH/g
#
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Retrieved document content: HAZARDOUS OPERATIONS & PREVENTIVE MEASURES
# Always use standard protective gear (workwear, helmet, safety boots, protective glasses, and face shield when handling any product) and standard chemical protection gloves. If you come into contact with any product, wash immediately and seek medical attention. TABLE DATA: MANUFACTURING PROCEDURE
# Review: 9
# Date: 08/02/2021 | CONFIDENTIAL
# PRODUCT: ALKYLBENZEN SULFONIC ACID (11027563)
# TABLE DATA:
# PLANT : | SULFAX
# REACTOR : | R503
# TABLE DATA:
# HAZARD CLASSIF
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Retrieved document content: HAZARDOUS OPERATIONS & PREVENTIVE MEASURES
# Always use standard protective gear (workwear, helmet, safety boots, protective glasses, and face shield when handling any product) and standard chemical protection gloves. If you come into contact with any product, wash immediately and seek medical attention. TABLE DATA: MANUFACTURING PROCEDURE
# Review: 9
# Date: 08/02/2021 | CONFIDENTIAL
# PRODUCT: ALKYLBENZEN SULFONIC ACID (11027563)
# TABLE DATA:
# PLANT : | SULFAX
# REACTOR : | R503
# TABLE DATA:
# HAZARD CLASSIF
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Retrieved document content: HAZARDOUS OPERATIONS & PREVENTIVE MEASURES
# Always use standard protective gear (workwear, helmet, safety boots, protective glasses, and face shield when handling any product) and standard chemical protection gloves. If you come into contact with any product, wash immediately and seek medical attention. TABLE DATA: MANUFACTURING PROCEDURE
# Review: 9
# Date: 08/02/2021 | CONFIDENTIAL
# PRODUCT: ALKYLBENZEN SULFONIC ACID (11027563)
# TABLE DATA:
# PLANT : | SULFAX
# REACTOR : | R503
# TABLE DATA:
# HAZARD CLASSIF
# INFO:query_engine:Retrieved document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'e465b618-0315-11f0-8522-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '49118bf7-f162-433b-810f-c37657f168ab'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 83DCD52176214CD783B465BACCD41144 Ref B: AMS231032609017 Ref C: 2025-03-17T09:55:01Z'
#     'Date': 'Mon, 17 Mar 2025 09:55:02 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'e694339f-0315-11f0-8c2d-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '38fa7184-bb96-4587-8ac3-7eeb8f96d109'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 3ACC72BF1AA54B4CAF3FBABA7A29FB66 Ref B: AMS231032609017 Ref C: 2025-03-17T09:55:03Z'
#     'Date': 'Mon, 17 Mar 2025 09:55:06 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '7622'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'e8c5cd5b-0315-11f0-a2fa-f8b54d499b92'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b9 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '928'
#     'Content-Type': 'application/json'
#     'openai-internal-engine-weight': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'x-accel-buffering': 'REDACTED'
#     'x-ms-rai-invoked': 'REDACTED'
#     'x-request-id': 'REDACTED'
#     'azureml-destination-model-group': 'REDACTED'
#     'azureml-destination-region': 'REDACTED'
#     'azureml-destination-deployment': 'REDACTED'
#     'azureml-destination-endpoint': 'REDACTED'
#     'azureml-model-deployment': 'REDACTED'
#     'azureml-model-session': 'REDACTED'
#     'azureml-model-group': 'REDACTED'
#     'x-envoy-upstream-service-time': 'REDACTED'
#     'x-ms-client-request-id': '8c3a28e0-f089-408f-90f5-e760ef9e821d'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'x-ratelimit-remaining-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'Date': 'Mon, 17 Mar 2025 09:55:08 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '7616'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'e9dc37ff-0315-11f0-8778-f8b54d499b92'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b9 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'request-context': 'REDACTED'
#     'prompt_token_len': 'REDACTED'
#     'sampling_token_len': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Mon, 17 Mar 2025 09:55:09 GMT'
# INFO:query_engine:Deduplicated document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Deduplicated document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:No. of sources with metadata: 2
# INFO:query_engine:Final document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# INFO:query_engine:Final document metadata: {'Date': '08/02/2021', 'Document Name': 'Alkylbenzen Sulfonic Acid', 'Review': '9'}
# ================================================================================
# Processing Query: Which range of humidity values are acceptable for the Alkylbenzen Sulfonic Acid?
# ================================================================================
# Final Answer: * Acceptable humidity range for Alkylbenzen Sulfonic Acid: 0.5-2%
# * Confidence: 100%
# Confidence: 100 %
# Source Documents Metadata:
# ----------------------------------------
# Date: 08/02/2021
# Document Name: Alkylbenzen Sulfonic Acid
# Review: 9
# ----------------------------------------
# Date: 08/02/2021
# Document Name: Alkylbenzen Sulfonic Acid
# Review: 9
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# WARNING:query_engine:Error calculating LLM relevance score: could not convert string to float: '7\n\nThe document provides information about the hazard classification of the AN-84 product, which directly addresses parts of the queries. However, it does not explicitly state where or according to whose regulations these classifications comply, so it is not fully relevant to all aspects of the sub-queries.'
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:Retrieved document content: MANUFACTURING PROCEDURE
# Review: 24
# Date: 24/04/2021 | CONFIDENTIAL
# PRODUCTO: AN-84 (10939987)
# TABLE DATA:
# PLANT : | POLISAL3
# REACTOR : | R003 | R002
# TABLE DATA:
# HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | HAZARD CLASSIFICATION OF THE FINAL PRODUCT: | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swallowed. H314 Causes severe skin burns and eye damage. H400 Very toxic to aquatic organisms. | H302 Harmful if swall
# INFO:query_engine:Retrieved document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:azure.identity._credentials.environment:Incomplete environment configuration for EnvironmentCredential. These variables are set: AZURE_TENANT_ID
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.20.0 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections?api-version=REDACTED&category=REDACTED&includeAll=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '05e2d71c-0317-11f0-bef7-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '3387'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-reads': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-reads': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': 'f3de40f9-09b6-430f-b773-b9c55a27586c'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 7AB5A753C2E8450F85B3F9D029D5F1C1 Ref B: AMS231020512017 Ref C: 2025-03-17T10:03:07Z'
#     'Date': 'Mon, 17 Mar 2025 10:03:07 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b98e9951-860f-464a-a9a2-f69802ca8721/resourceGroups/ai_llm/providers/Microsoft.MachineLearningServices/workspaces/agentic_rag/connections/kdgTheLab/listsecrets?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '21'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '079ec974-0317-11f0-b0b3-f8b54d499b92'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b6 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '1625'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-global-writes': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-writes': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '34e7dc1d-e817-46d5-9fce-9ce6afec031f'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'X-Cache': 'REDACTED'
#     'X-MSEdge-Ref': 'Ref A: 39FFAAC0FA94494CA3CFFA4693F531EC Ref B: AMS231020512017 Ref C: 2025-03-17T10:03:08Z'
#     'Date': 'Mon, 17 Mar 2025 10:03:08 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3754'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '082615a1-0317-11f0-b19d-f8b54d499b92'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b9 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '1051'
#     'Content-Type': 'application/json'
#     'openai-internal-engine-weight': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'x-accel-buffering': 'REDACTED'
#     'x-ms-rai-invoked': 'REDACTED'
#     'x-request-id': 'REDACTED'
#     'azureml-destination-model-group': 'REDACTED'
#     'azureml-destination-region': 'REDACTED'
#     'azureml-destination-deployment': 'REDACTED'
#     'azureml-destination-endpoint': 'REDACTED'
#     'azureml-model-deployment': 'REDACTED'
#     'azureml-model-session': 'REDACTED'
#     'azureml-model-group': 'REDACTED'
#     'x-envoy-upstream-service-time': 'REDACTED'
#     'x-ms-client-request-id': '1c9fcd88-ad06-4916-88c1-d07fa26e835d'
#     'apim-request-id': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-ratelimit-remaining-requests': 'REDACTED'
#     'x-ratelimit-limit-requests': 'REDACTED'
#     'x-ratelimit-remaining-tokens': 'REDACTED'
#     'x-ratelimit-limit-tokens': 'REDACTED'
#     'Date': 'Mon, 17 Mar 2025 10:03:10 GMT'
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kdgthelab.cognitiveservices.azure.com/models/chat/completions?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '3748'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '094c006b-0317-11f0-aff1-f8b54d499b92'
#     'api-key': 'REDACTED'
#     'User-Agent': 'AIProjectClient azsdk-python-ai-inference/1.0.0b9 Python/3.12.7 (Windows-11-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json'
#     'Content-Encoding': 'REDACTED'
#     'Vary': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'request-context': 'REDACTED'
#     'prompt_token_len': 'REDACTED'
#     'sampling_token_len': 'REDACTED'
#     'x-content-type-options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Mon, 17 Mar 2025 10:03:12 GMT'
# INFO:query_engine:Deduplicated document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# INFO:query_engine:No. of sources with metadata: 1
# INFO:query_engine:Final document metadata: {'Date': '24/04/2021', 'Document Name': 'AN-84-24', 'Review': '24'}
# ================================================================================
# Processing Query: Describe the hazard classification of the AN-84 product.
# ================================================================================
# Final Answer: * The hazard classification of the AN-84 product includes H302, H314, and H400 labels.
# * H302 indicates that the substance is harmful if swallowed.
# * H314 signifies that it causes severe skin burns and eye damage.
# * H400 highlights its extreme toxicity towards aquatic organisms.
# Confidence: 100 %
# Source Documents Metadata:
# ----------------------------------------
# Date: 24/04/2021
# Document Name: AN-84-24
# Review: 24
